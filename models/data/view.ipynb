# %%
import pandas as pd

# %%
data=pd.read_csv('RandomForest_Regression_Grid_42_Original_best_predictions.csv')
data2=pd.read_csv('RandomForest_Regression_Grid_42_Original_predictions.csv')

# %%
data[["y_true", "y_pred"]]
# Out:
#      y_true       y_pred
# 0    7200.0  4624.643598
# 1    4680.0  6553.670653
# 2    3960.0  5926.987475
# 3    6840.0  5351.158662
# 4    3600.0  6874.824565
# ..      ...          ...
# 139  3960.0  5712.768085
# 140  4680.0  6424.164188
# 141  3960.0  5570.962995
# 142  3960.0  6669.307280
# 143  7200.0  5320.396086
#
# [144 rows x 2 columns]
