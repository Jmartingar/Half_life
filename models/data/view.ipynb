# %%
import pandas as pd

# %%
data=pd.read_csv('data_independent.csv')
data2=pd.read_csv('excluded_homology.csv')

# %%
data2
# Out:
#                                  sequence experimental_characteristics  \
# 0                    AAHLIDALYAEFLGGRVLTT                    Mammalian
# 1                          ADLEVVAATHVLVA                    Mammalian
# 2                             ADLEVVAATYV                    Mammalian
# 3                          ADLEVVAATYVDDD                    Mammalian
# 4                          ADLEVVAATYVDVA                    Mammalian
# ..                                    ...                          ...
# 611  YTSLIHSLIEEWQNQQEKNEQELLELDKWASLWNWF                        Yeast
# 612  YTSLIHSLIEEWQNQQEKNEQELLELDKWASLWNWF                       E_coli
# 613  YTSLIHSLIEEYQNQQEKNEQELLELDKWASLWNWF                       E_coli
# 614  YTSLIHSLIEEYQNQQEKNEQELLELDKWASLWNWF                    Mammalian
# 615  YTSLIHSLIEEYQNQQEKNEQELLELDKWASLWNWF                        Yeast
#
#      half_life_seconds  length_sequence  target
# 0              15840.0               20       1
# ...
