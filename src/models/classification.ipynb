# %%
import pandas as pd 
import sys
sys.path.insert(0, "")
from src.training_models.optimization_models import OptimizationProcess

# %%
repr_name="ProtT5"
df_data = pd.read_csv(f"../../data/numerical_rep/{repr_name}.csv")
df_data.drop(["experimental_characteristics"], axis=1, inplace=True)
print(f"Running optimization for Prot5, Random Forest")
model_instance = OptimizationProcess(df_data=df_data)
try:
    model_instance.run_optimization(
        type_encoder="emedding", 
        encoder="Prot5",
        algorithm="RandomForest"
    )
except Exception as e:
    print(f"Error during optimization for Prot5, Random Forest: {e}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       2 df_data = pd.read_csv(f"../../data/numerical_rep/{repr_name}.csv")
#       3 df_data.drop(["experimental_characteristics"], axis=1, inplace=True)
# ----> 4 print(f"Running optimization for Prot5: {encoder}, Algorithm: {algorithm}")
#       5 model_instance = OptimizationProcess(df_data=df_data)
#       6 try:
#
# NameError: name 'encoder' is not defined
